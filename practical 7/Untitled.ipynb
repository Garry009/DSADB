# %% [markdown]
# Name : Gaurav Santosh Mane RollNo:13253

# %%
import nltk
import re

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Gaurav\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Gaurav\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Gaurav\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Gaurav\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Gaurav\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
text = """Tokenization is the first step in text analytics. 
The process of breaking down a text paragraph into smaller chunks 
such as words or sentences is called Tokenization."""

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
sentences = sent_tokenize(text)
print("Sentence Tokenization:\n", sentences)
# Out:
# Sentence Tokenization:
#  ['Tokenization is the first step in text analytics.', 'The process of breaking down a text paragraph into smaller chunks \nsuch as words or sentences is called Tokenization.']

# %%
words = word_tokenize(text)
print("\nWord Tokenization:\n", words)
# Out:
# Word Tokenization:
#  ['Tokenization', 'is', 'the', 'first', 'step', 'in', 'text', 'analytics', '.', 'The', 'process', 'of', 'breaking', 'down', 'a', 'text', 'paragraph', 'into', 'smaller', 'chunks', 'such', 'as', 'words', 'or', 'sentences', 'is', 'called', 'Tokenization', '.']

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))

# %%
clean_text = re.sub('[^a-zA-Z]', ' ', text)

# %%
tokens = word_tokenize(clean_text.lower())

# %%
filtered_words = [w for w in tokens if w not in stop_words]
print("\nFiltered Words:\n", filtered_words)
# Out:
# Filtered Words:
#  ['tokenization', 'first', 'step', 'text', 'analytics', 'process', 'breaking', 'text', 'paragraph', 'smaller', 'chunks', 'words', 'sentences', 'called', 'tokenization']

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()
stemmed_words = [ps.stem(w) for w in filtered_words]
print("\nStemmed Words:\n", stemmed_words)
# Out:
# Stemmed Words:
#  ['token', 'first', 'step', 'text', 'analyt', 'process', 'break', 'text', 'paragraph', 'smaller', 'chunk', 'word', 'sentenc', 'call', 'token']

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(w) for w in filtered_words]
print("\nLemmatized Words:\n", lemmatized_words)
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# Lemmatized Words:
#  ['tokenization', 'first', 'step', 'text', 'analytics', 'process', 'breaking', 'text', 'paragraph', 'smaller', 'chunk', 'word', 'sentence', 'called', 'tokenization']
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Gaurav\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
pos_tags = nltk.pos_tag(filtered_words)
print("\nPOS Tagging:\n", pos_tags)
# Out:
# POS Tagging:
#  [('tokenization', 'NN'), ('first', 'RB'), ('step', 'VB'), ('text', 'JJ'), ('analytics', 'NNS'), ('process', 'NN'), ('breaking', 'VBG'), ('text', 'NN'), ('paragraph', 'NN'), ('smaller', 'JJR'), ('chunks', 'NNS'), ('words', 'NNS'), ('sentences', 'NNS'), ('called', 'VBD'), ('tokenization', 'NN')]

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
documentA = 'Jupiter is the largest Planet'
documentB = 'Mars is the fourth planet from the Sun'

# %%
bagOfWordsA = documentA.split(' ')
bagOfWordsB = documentB.split(' ')
print("Bag A",bagOfWordsA)
print("Bag B",bagOfWordsB)
# Out:
# Bag A ['Jupiter', 'is', 'the', 'largest', 'Planet']
# Bag B ['Mars', 'is', 'the', 'fourth', 'planet', 'from', 'the', 'Sun']

# %%
uniqueWords = set(bagOfWordsA).union(set(bagOfWordsB))
print("Unique Words",uniqueWords)
# Out:
# Unique Words {'is', 'Planet', 'Mars', 'planet', 'from', 'largest', 'Sun', 'the', 'fourth', 'Jupiter'}

# %%
numOfWordsA = dict.fromkeys(uniqueWords, 0)
for word in bagOfWordsA:numOfWordsA[word] += 1
print("numOfWordsA",numOfWordsA)

numOfWordsB = dict.fromkeys(uniqueWords, 0)
for word in bagOfWordsB:numOfWordsB[word] += 1
print("numOfWordsB",numOfWordsB)
# Out:
# numOfWordsA {'is': 1, 'Planet': 1, 'Mars': 0, 'planet': 0, 'from': 0, 'largest': 1, 'Sun': 0, 'the': 1, 'fourth': 0, 'Jupiter': 1}
# numOfWordsB {'is': 1, 'Planet': 0, 'Mars': 1, 'planet': 1, 'from': 1, 'largest': 0, 'Sun': 1, 'the': 2, 'fourth': 1, 'Jupiter': 0}
