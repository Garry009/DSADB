# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("custom_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   math_score       95 non-null     float64
#  1   reading_score    100 non-null    int64
#  2   writing_score    100 non-null    int64
#  3   clubing          90 non-null     float64
#  4   placement_score  95 non-null     float64
#  5   placement_offer  100 non-null    int64
#  6   gender           100 non-null    int64
# dtypes: float64(3), int64(4)
# memory usage: 5.6 KB

# %%
df.isnull()
# Out:
#     math_score  reading_score  writing_score  clubing  placement_score  \
# 0        False          False          False    False            False
# 1        False          False          False    False            False
# 2        False          False          False    False            False
# 3        False          False          False    False            False
# 4        False          False          False    False            False
# ..         ...            ...            ...      ...              ...
# 95       False          False          False    False            False
# 96       False          False          False    False            False
# 97       False          False          False    False            False
# 98       False          False          False    False            False
# 99       False          False          False    False            False
#
#     placement_offer  gender
# 0             False   False
# 1             False   False
# ...

# %%
df.math_score
# Out:
# 0     74.0
# 1     79.0
# 2     66.0
# 3     64.0
# 4     80.0
#       ...
# 95    79.0
# 96    78.0
# 97    76.0
# 98    73.0
# 99    61.0
# Name: math_score, Length: 100, dtype: float64

# %%
x=df.math_score.min()

# %%
x
# Out:
# np.float64(60.0)

# %%
df.math_score.isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: math_score, Length: 100, dtype: bool

# %%
df.isnull().sum()
# Out:
# math_score          5
# reading_score       0
# writing_score       0
# clubing            10
# placement_score     5
# placement_offer     0
# gender              0
# dtype: int64

# %%
df.writing_score.min()
# Out:
# np.int64(60)

# %%
x=df.writing_score.min()

# %%
y=df.writing_score.fillna(x)

# %%
y
# Out:
# 0     77
# 1     69
# 2     71
# 3     69
# 4     66
#       ..
# 95    70
# 96    62
# 97    69
# 98    75
# 99    70
# Name: writing_score, Length: 100, dtype: int64

# %%
df.placement_score.isnull().sum()
# Out:
# np.int64(5)

# %%
x=df.placement_score.min()

# %%
x
# Out:
# np.float64(75.0)

# %%
y=df.placement_score.fillna(x)

# %%
y
# Out:
# 0     89.0
# 1     98.0
# 2     82.0
# 3     84.0
# 4     85.0
#       ...
# 95    80.0
# 96    89.0
# 97    96.0
# 98    89.0
# 99    81.0
# Name: placement_score, Length: 100, dtype: float64

# %%
a=df['math_score'].mean()

# %%
a
# Out:
# np.float64(69.96842105263158)

# %%
df['math_score'].fillna(77,inplace=True)

# %%
df
# Out:
#     math_score  reading_score  writing_score  clubing  placement_score  \
# 0         74.0             84             77   2020.0             89.0
# 1         79.0             86             69   2023.0             98.0
# 2         66.0             91             71   2022.0             82.0
# 3         64.0             77             69   2021.0             84.0
# 4         80.0             88             66   2021.0             85.0
# ..         ...            ...            ...      ...              ...
# 95        79.0             77             70   2022.0             80.0
# 96        78.0             86             62   2024.0             89.0
# 97        76.0             80             69   2020.0             96.0
# 98        73.0             84             75   2022.0             89.0
# 99        61.0             81             70   2021.0             81.0
#
#     placement_offer  gender
# 0                 3       1
# 1                 3       0
# ...

# %%
df.math_score.isnull().sum()
# Out:
# np.int64(0)

# %%
df.fillna({'reading_score':70}, inplace=True)

# %%
df
# Out:
#     math_score  reading_score  writing_score  clubing  placement_score  \
# 0         74.0             84             77   2020.0             89.0
# 1         79.0             86             69   2023.0             98.0
# 2         66.0             91             71   2022.0             82.0
# 3         64.0             77             69   2021.0             84.0
# 4         80.0             88             66   2021.0             85.0
# ..         ...            ...            ...      ...              ...
# 95        79.0             77             70   2022.0             80.0
# 96        78.0             86             62   2024.0             89.0
# 97        76.0             80             69   2020.0             96.0
# 98        73.0             84             75   2022.0             89.0
# 99        61.0             81             70   2021.0             81.0
#
#     placement_offer  gender
# 0                 3       1
# 1                 3       0
# ...

# %%
df.reading_score.isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# math_score         0
# reading_score      0
# writing_score      0
# clubing            0
# placement_score    0
# placement_offer    0
# gender             0
# dtype: int64

# %%
x=df.placement_score.min()

# %%
df.fillna({'placement_score':x}, inplace=True)

# %%
df.placement_score.isnull().sum()
# Out:
# np.int64(0)

# %%
x=df.clubing.min()

# %%
df.fillna({'clubing':x}, inplace=True)

# %%
df.clubing.isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# math_score         0
# reading_score      0
# writing_score      0
# clubing            0
# placement_score    0
# placement_offer    0
# gender             0
# dtype: int64

# %%
col=['math_score','reading_score','writing_score','placement_score']
df
# Out:
#     math_score  reading_score  writing_score  clubing  placement_score  \
# 0         74.0             84             77   2020.0             89.0
# 1         79.0             86             69   2023.0             98.0
# 2         66.0             91             71   2022.0             82.0
# 3         64.0             77             69   2021.0             84.0
# 4         80.0             88             66   2021.0             85.0
# ..         ...            ...            ...      ...              ...
# 95        79.0             77             70   2022.0             80.0
# 96        78.0             86             62   2024.0             89.0
# 97        76.0             80             69   2020.0             96.0
# 98        73.0             84             75   2022.0             89.0
# 99        61.0             81             70   2021.0             81.0
#
#     placement_offer  gender
# 0                 3       1
# 1                 3       0
# ...

# %%
df.boxplot(col)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 df.boxplot(col)
#       2 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\plotting\_core.py:533, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     516 @Substitution(data="", backend=_backend_doc)
#     517 @Appender(_boxplot_doc)
#     518 def boxplot_frame(
#    (...)    530     **kwargs,
#     531 ):
#     532     plot_backend = _get_plot_backend(backend)
# --> 533     return plot_backend.boxplot_frame(
#     534         self,
#     535         column=column,
#     536         by=by,
#     537         ax=ax,
#     538         fontsize=fontsize,
#     539         rot=rot,
#     540         grid=grid,
#     541         figsize=figsize,
#     542         layout=layout,
# ...

# %%
print(np.where(df['math_score']>90))
print(np.where(df['reading_score']<25))
print(np.where(df['writing_score']<30))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
import matplotlib.pyplot as plt

# %%
fig,ax= plt.subplots(figsize=(18,10))

# %%
ax.scatter(df['placement_score'], df['placement_offer'])
plt.show()

# %%
print(np.where((df['placement_score']<50) & (df['placement_offer']>1)))
print(np.where((df['placement_score']>85) & (df['placement_offer']<3)))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
from scipy import stats

# %%
z = np.abs(stats.zscore(df['math_score']))

# %%
print(z)
# Out:
# [0.60419192 1.42510485 0.70926877 1.03763395 1.58928744 0.21672101
#  1.53018171 0.3809036  1.69436429 0.70926877 0.27582675 1.03763395
#  0.27582675 1.42510485 0.60419192 1.20181653 0.21672101 0.44000933
#  0.54508619 0.21672101 1.09673968 0.54508619 0.60419192 1.03763395
#  0.11164416 1.58928744 1.58928744 0.27582675 1.09673968 1.09673968
#  1.09673968 1.09673968 1.09673968 1.53018171 1.69436429 1.36599912
#  1.03763395 0.21672101 0.11164416 1.58928744 1.36599912 1.20181653
#  0.3809036  0.44000933 1.03763395 0.93255709 0.21672101 0.27582675
#  1.20181653 1.58928744 1.20181653 1.03763395 0.54508619 1.42510485
#  0.87345136 1.42510485 1.42510485 0.70926877 0.44000933 0.05253843
#  0.11164416 1.42510485 0.54508619 1.36599912 0.21672101 0.54508619
#  0.93255709 1.53018171 0.3809036  0.87345136 1.20181653 1.03763395
#  0.05253843 0.7683745  0.44000933 1.69436429 0.3809036  0.11164416
#  1.58928744 0.70926877 0.93255709 1.09673968 0.54508619 0.27582675
# ...
